# %%
"""
Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with
an example.
- A function which gives value of probability for particular datapoint (x) is probability funciton basically.
if it is derived for discrete random variable then it is probability mass function(pmf) and if it is derived for continuos random
variable it is probability density function(pdf)

example:
pmf - what is probability of getting 1 if dice is thrown having sample space {1,2,3,4,5,6}
pdf - what is probability that IQ of specific indian state falls between [85-100]


Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?

Cumulative density function is summation of probability at each increasing point. its range is simply (0,1)
it is used when we have see probability till specific set of datapoints not only one single datapoint

Q3: What are some examples of situations where the normal distribution might be used as a model?
Explain how the parameters of the normal distribution relate to the shape of the distribution.

Normal distribution can be used as model for analyzing data of Intelligent-Quotient of India/specific country
Or for test scores , or mostly for Quality control

As from empirical rule of normal distribution,
mean=mode=median is at center 
and 50 % of area is distributed in both of sections...
as standard deviation moves towards right data distribution goes on decreasing on both directions...
so thats why it becomes bell-shaped..

Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal
Distribution.

Normal Distribution is a ideal and best distribution for any dataset..
So, it sets a reference for any data where it should go...
that is the most important aspect of normal distribution...

Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli
Distribution and Binomial Distribution?

Bernoulli distribution is special case of binomial distribution when n = 1.
it is also used to calculate probabilities of events which are independent 

suppose we have to calculate probability of getting 1 head in one toss if P(H) = 0.8 and obviously P(T) = 0.2

Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset
is normally distributed, what is the probability that a randomly selected observation will be greater
than 60? Use the appropriate formula and show your calculations.

so lets calculate Z-score for 60 
it will be (xi - mean)/s.d = (60-50)/10 = 1

z- score = 1
so, after checking in Z-table area below standard normal 1 is almost 84%
So Probability that any selected random variable is greater than 60 will be 100% - 84% = "16%" or 0.16

Q7: Explain uniform Distribution with an example.

Uniform distribution is a termed to be rectangular distribution also...
its pdf is 1/(b-a) and pmf is 1/n where n = b-a+1

if a and b are min and max of datapoints then probability for each data point between a and b or in interval [a,b] is 
1/b-a

one simple example of discrete uniform distribution is
tossing a dice = {1,2,3,4,5,6}

min = 1 max = 6

probability = 1/6-1+1 = 1/6

Q8: What is the z score? State the importance of the z score.

Z-score is used to convert Normal distribution into standard normal distribution.
It simply shifts normal distribution with any mean X on origin...and it becomes easier for probability calculation purpose 

Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.

if we take n samples from normal distribution and for each sample we calculated a mean like x1 , x2 , x3, ,....xn

and we plotted those n sample means on graph then it will again form a normal distribution with mean almost equal to population
data and standrad deviation = sigma/root(n)

this is the concept of central limit theorem


incase of non-gaussian distributions if sample size n >= 30 then Central limit theorem is applicable.

Q10: State the assumptions of the Central Limit Theorem.

ndependence: The random variables in the sample must be independent of each other. This means that the outcome of one observation does not influence the outcome of another observation.

Identically Distributed: Each random variable in the sample must be drawn from the same probability distribution. This ensures that they have the same mean (
�
μ) and variance (
�
2
σ 
2
 ).

Finite Variance: The random variables must have finite variances. This assumption ensures that the sample mean or sum will also have a finite variance, which is necessary for the convergence described by the Central Limit Theorem.

Large Sample Size: The Central Limit Theorem applies as the sample size (
�
n) becomes sufficiently large. While there is no fixed threshold for what constitutes a "large" sample size, a common rule of thumb is that the sample size should be greater than 30. However, even for smaller sample sizes, the CLT can often provide reasonable approximations if the underlying population distribution is not heavily skewed or has significant outliers.



"""
